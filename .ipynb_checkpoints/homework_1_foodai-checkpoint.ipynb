# %% [markdown]
# # Food AI

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.metrics import error_rate
import pandas as pd

# %%
bs = 64
# bs = 16   # uncomment this line if you run out of memory even after clicking Kernel->Restart

# %%
path = untar_data("https://s3.amazonaws.com/fast-ai-imageclas/food-101"); path
# Out:
# PosixPath('/home/jupyter/.fastai/data/food-101')

# %%
path.ls()
# Out:
# [PosixPath('/home/jupyter/.fastai/data/food-101/test.txt'),
#  PosixPath('/home/jupyter/.fastai/data/food-101/labels.txt'),
#  PosixPath('/home/jupyter/.fastai/data/food-101/train.txt'),
#  PosixPath('/home/jupyter/.fastai/data/food-101/test.json'),
#  PosixPath('/home/jupyter/.fastai/data/food-101/images'),
#  PosixPath('/home/jupyter/.fastai/data/food-101/train.json'),
#  PosixPath('/home/jupyter/.fastai/data/food-101/h5'),
#  PosixPath('/home/jupyter/.fastai/data/food-101/classes.txt')]

# %%
path_img = path/'images'

# %%
train_df = pd.read_csv(path/'train.txt', header=None, names=['label', 'name'])
train_df['name'] = train_df['label'].astype(str) + ".jpg"
train_df['label'] = train_df.label.str.split("/").str[0]

test_df = pd.read_csv(path/'test.txt', header=None, names=['label', 'name'])
test_df['name'] = test_df['label'].astype(str) + ".jpg"
test_df['label'] = test_df.label.str.split("/").str[0]

train_df[:5]
# Out:
#        label                   name
# 0  apple_pie  apple_pie/1005649.jpg
# 1  apple_pie  apple_pie/1014775.jpg
# 2  apple_pie  apple_pie/1026328.jpg
# 3  apple_pie  apple_pie/1028787.jpg
# 4  apple_pie  apple_pie/1043283.jpg

# %% [markdown]
# We construct an ImageDataBunch from the train.txt file, and getting the corresponding image for each line.

# %%
ds_tfms = ([RandTransform(tfm=TfmCrop (crop_pad), kwargs={'row_pct': (0, 1), 'col_pct': (0, 1), 'padding_mode': 'reflection'}, p=1.0, resolved={}, do_run=True, is_random=True), 
            RandTransform(tfm=TfmAffine (flip_affine), kwargs={}, p=0.5, resolved={}, do_run=True, is_random=True), 
            RandTransform(tfm=TfmCoord (symmetric_warp), kwargs={'magnitude': (-0.2, 0.2)}, p=0.75, resolved={}, do_run=True, is_random=True), 
            RandTransform(tfm=TfmAffine (rotate), kwargs={'degrees': (-10.0, 10.0)}, p=0.75, resolved={}, do_run=True, is_random=True), 
            RandTransform(tfm=TfmAffine (zoom), kwargs={'scale': (1.0, 1.1), 'row_pct': (0, 1), 'col_pct': (0, 1)}, p=0.75, resolved={}, do_run=True, is_random=True), 
            RandTransform(tfm=TfmLighting (brightness), kwargs={'change': (0.4, 0.6)}, p=0.75, resolved={}, do_run=True, is_random=True), 
            RandTransform(tfm=TfmLighting (contrast), kwargs={'scale': (0.8, 1.25)}, p=0.75, resolved={}, do_run=True, is_random=True)], 
           [RandTransform(tfm=TfmCrop (crop_pad), kwargs={}, p=1.0, resolved={}, do_run=True, is_random=True)])

# %%
data = (ImageList.from_df(df=train_df, path=path/'images', cols=1)
       .split_by_rand_pct(0.2)
       .label_from_df(cols=0)
       .transform(ds_tfms, size=224)
       .databunch(bs=bs)
       .normalize(imagenet_stats))

# %%
data.show_batch(rows=3, figsize=(10, 10))

# %%
print(data.classes)
len(data.classes),data.c
# Out:
# ['apple_pie', 'baby_back_ribs', 'baklava', 'beef_carpaccio', 'beef_tartare', 'beet_salad', 'beignets', 'bibimbap', 'bread_pudding', 'breakfast_burrito', 'bruschetta', 'caesar_salad', 'cannoli', 'caprese_salad', 'carrot_cake', 'ceviche', 'cheese_plate', 'cheesecake', 'chicken_curry', 'chicken_quesadilla', 'chicken_wings', 'chocolate_cake', 'chocolate_mousse', 'churros', 'clam_chowder', 'club_sandwich', 'crab_cakes', 'creme_brulee', 'croque_madame', 'cup_cakes', 'deviled_eggs', 'donuts', 'dumplings', 'edamame', 'eggs_benedict', 'escargots', 'falafel', 'filet_mignon', 'fish_and_chips', 'foie_gras', 'french_fries', 'french_onion_soup', 'french_toast', 'fried_calamari', 'fried_rice', 'frozen_yogurt', 'garlic_bread', 'gnocchi', 'greek_salad', 'grilled_cheese_sandwich', 'grilled_salmon', 'guacamole', 'gyoza', 'hamburger', 'hot_and_sour_soup', 'hot_dog', 'huevos_rancheros', 'hummus', 'ice_cream', 'lasagna', 'lobster_bisque', 'lobster_roll_sandwich', 'macaroni_and_cheese', 'macarons', 'miso_soup', 'mussels', 'nachos', 'omelette', 'onion_rings', 'oysters', 'pad_thai', 'paella', 'pancakes', 'panna_cotta', 'peking_duck', 'pho', 'pizza', 'pork_chop', 'poutine', 'prime_rib', 'pulled_pork_sandwich', 'ramen', 'ravioli', 'red_velvet_cake', 'risotto', 'samosa', 'sashimi', 'scallops', 'seaweed_salad', 'shrimp_and_grits', 'spaghetti_bolognese', 'spaghetti_carbonara', 'spring_rolls', 'steak', 'strawberry_shortcake', 'sushi', 'tacos', 'takoyaki', 'tiramisu', 'tuna_tartare', 'waffles']
# (101, 101)

# %% [markdown]
# ## Training: resnet34

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.372282</td>
#       <td>1.857859</td>
#       <td>0.470231</td>
#       <td>06:28</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.915565</td>
#       <td>1.546688</td>
#       <td>0.398218</td>
#       <td>06:28</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.657033</td>
#       <td>1.398188</td>
#       <td>0.360858</td>
#       <td>06:27</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.542715</td>
#       <td>1.357254</td>
#       <td>0.351551</td>
#       <td>06:22</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %% [markdown]
# ## Results

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses, idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
interp.most_confused(min_val=2)
# Out:
# [('paella', 'fried_rice', 20),
#  ('apple_pie', 'bread_pudding', 19),
#  ('filet_mignon', 'steak', 19),
#  ('prime_rib', 'steak', 17),
#  ('steak', 'filet_mignon', 17),
#  ('tuna_tartare', 'beef_tartare', 17),
#  ('pork_chop', 'steak', 15),
#  ('chocolate_mousse', 'chocolate_cake', 14),
#  ('ice_cream', 'frozen_yogurt', 14),
#  ('panna_cotta', 'chocolate_mousse', 14),
#  ('beef_carpaccio', 'beet_salad', 13),
#  ('cheesecake', 'panna_cotta', 13),
#  ('apple_pie', 'waffles', 12),
#  ('cheesecake', 'strawberry_shortcake', 12),
#  ('chocolate_cake', 'chocolate_mousse', 12),
#  ('dumplings', 'gyoza', 12),
#  ('lobster_bisque', 'clam_chowder', 12),
#  ('pho', 'ramen', 12),
#  ('shrimp_and_grits', 'gnocchi', 12),
#  ('crab_cakes', 'scallops', 11),
#  ('filet_mignon', 'pork_chop', 11),
#  ('hamburger', 'pulled_pork_sandwich', 11),
#  ('pork_chop', 'filet_mignon', 11),
#  ('beef_tartare', 'tuna_tartare', 10),
#  ('donuts', 'beignets', 10),
#  ('foie_gras', 'pork_chop', 10),
#  ('fried_calamari', 'onion_rings', 10),
#  ('greek_salad', 'caesar_salad', 10),
#  ('pancakes', 'french_toast', 10),
#  ('strawberry_shortcake', 'cheesecake', 10),
#  ('baby_back_ribs', 'steak', 9),
#  ('bread_pudding', 'apple_pie', 9),
#  ('caprese_salad', 'beef_carpaccio', 9),
#  ('caprese_salad', 'greek_salad', 9),
#  ('carrot_cake', 'cup_cakes', 9),
#  ('chocolate_mousse', 'tiramisu', 9),
#  ('crab_cakes', 'pork_chop', 9),
#  ('greek_salad', 'beet_salad', 9),
#  ('hummus', 'chicken_quesadilla', 9),
#  ('ice_cream', 'chocolate_mousse', 9),
#  ('lasagna', 'french_onion_soup', 9),
#  ('lasagna', 'pizza', 9),
#  ('pulled_pork_sandwich', 'grilled_cheese_sandwich', 9),
#  ('pulled_pork_sandwich', 'hamburger', 9),
#  ('red_velvet_cake', 'carrot_cake', 9),
#  ('beef_tartare', 'beef_carpaccio', 8),
#  ('breakfast_burrito', 'chicken_quesadilla', 8),
#  ('caprese_salad', 'beet_salad', 8),
#  ('club_sandwich', 'grilled_cheese_sandwich', 8),
#  ('falafel', 'tacos', 8),
#  ('french_onion_soup', 'macaroni_and_cheese', 8),
#  ('grilled_cheese_sandwich', 'club_sandwich', 8),
#  ('pork_chop', 'baby_back_ribs', 8),
#  ('pork_chop', 'grilled_salmon', 8),
#  ('ravioli', 'lasagna', 8),
#  ('ravioli', 'scallops', 8),
#  ('red_velvet_cake', 'cup_cakes', 8),
#  ('scallops', 'shrimp_and_grits', 8),
#  ('steak', 'pork_chop', 8),
#  ('tacos', 'chicken_quesadilla', 8),
#  ('tacos', 'nachos', 8),
#  ('tiramisu', 'chocolate_cake', 8),
#  ('apple_pie', 'baklava', 7),
#  ('beet_salad', 'greek_salad', 7),
#  ('carrot_cake', 'chocolate_cake', 7),
#  ('cheesecake', 'tiramisu', 7),
#  ('chicken_curry', 'hot_and_sour_soup', 7),
#  ('chocolate_cake', 'carrot_cake', 7),
#  ('chocolate_mousse', 'panna_cotta', 7),
#  ('escargots', 'french_onion_soup', 7),
#  ('foie_gras', 'cheese_plate', 7),
#  ('greek_salad', 'ceviche', 7),
#  ('grilled_salmon', 'pork_chop', 7),
#  ('guacamole', 'ceviche', 7),
#  ('gyoza', 'samosa', 7),
#  ('hot_dog', 'tacos', 7),
#  ('huevos_rancheros', 'breakfast_burrito', 7),
#  ('nachos', 'pizza', 7),
#  ('onion_rings', 'fried_calamari', 7),
#  ('peking_duck', 'baby_back_ribs', 7),
#  ('prime_rib', 'baby_back_ribs', 7),
#  ('prime_rib', 'filet_mignon', 7),
#  ('ramen', 'bibimbap', 7),
#  ('risotto', 'fried_rice', 7),
#  ('scallops', 'crab_cakes', 7),
#  ('scallops', 'foie_gras', 7),
#  ('tiramisu', 'chocolate_mousse', 7),
#  ('tuna_tartare', 'nachos', 7),
#  ('waffles', 'strawberry_shortcake', 7),
#  ('apple_pie', 'french_toast', 6),
#  ('baklava', 'apple_pie', 6),
#  ('bread_pudding', 'french_toast', 6),
#  ('breakfast_burrito', 'omelette', 6),
#  ('breakfast_burrito', 'pulled_pork_sandwich', 6),
#  ('caesar_salad', 'greek_salad', 6),
#  ('ceviche', 'guacamole', 6),
#  ('ceviche', 'tacos', 6),
#  ('cheese_plate', 'foie_gras', 6),
#  ('chicken_wings', 'fish_and_chips', 6),
#  ('chocolate_cake', 'red_velvet_cake', 6),
#  ('clam_chowder', 'escargots', 6),
#  ('crab_cakes', 'beef_tartare', 6),
#  ('crab_cakes', 'falafel', 6),
#  ('crab_cakes', 'tuna_tartare', 6),
#  ('creme_brulee', 'french_onion_soup', 6),
#  ('foie_gras', 'french_toast', 6),
#  ('foie_gras', 'scallops', 6),
#  ('foie_gras', 'steak', 6),
#  ('french_toast', 'bread_pudding', 6),
#  ('french_toast', 'pancakes', 6),
#  ('gnocchi', 'shrimp_and_grits', 6),
#  ('grilled_salmon', 'baby_back_ribs', 6),
#  ('grilled_salmon', 'crab_cakes', 6),
#  ('huevos_rancheros', 'nachos', 6),
#  ('macaroni_and_cheese', 'french_onion_soup', 6),
#  ('nachos', 'guacamole', 6),
#  ('omelette', 'chicken_quesadilla', 6),
#  ('omelette', 'huevos_rancheros', 6),
#  ('pancakes', 'strawberry_shortcake', 6),
#  ('ravioli', 'shrimp_and_grits', 6),
#  ('red_velvet_cake', 'strawberry_shortcake', 6),
#  ('scallops', 'ravioli', 6),
#  ('seaweed_salad', 'beet_salad', 6),
#  ('shrimp_and_grits', 'chicken_curry', 6),
#  ('spaghetti_bolognese', 'pad_thai', 6),
#  ('spring_rolls', 'samosa', 6),
#  ('steak', 'baby_back_ribs', 6),
#  ('steak', 'prime_rib', 6),
#  ('sushi', 'sashimi', 6),
#  ('tacos', 'huevos_rancheros', 6),
#  ('tacos', 'lobster_roll_sandwich', 6),
#  ('tacos', 'pulled_pork_sandwich', 6),
#  ('tiramisu', 'red_velvet_cake', 6),
#  ('tuna_tartare', 'ceviche', 6),
#  ('beet_salad', 'tuna_tartare', 5),
#  ('bruschetta', 'caprese_salad', 5),
#  ('caprese_salad', 'bruschetta', 5),
#  ('caprese_salad', 'cannoli', 5),
#  ('caprese_salad', 'panna_cotta', 5),
#  ('carrot_cake', 'bread_pudding', 5),
#  ('ceviche', 'sushi', 5),
#  ('cheesecake', 'waffles', 5),
#  ('chicken_curry', 'paella', 5),
#  ('clam_chowder', 'hummus', 5),
#  ('clam_chowder', 'lobster_bisque', 5),
#  ('club_sandwich', 'churros', 5),
#  ('club_sandwich', 'hamburger', 5),
#  ('club_sandwich', 'pulled_pork_sandwich', 5),
#  ('crab_cakes', 'grilled_salmon', 5),
#  ('creme_brulee', 'panna_cotta', 5),
#  ('cup_cakes', 'donuts', 5),
#  ('cup_cakes', 'ice_cream', 5),
#  ('donuts', 'takoyaki', 5),
#  ('dumplings', 'samosa', 5),
#  ('eggs_benedict', 'croque_madame', 5),
#  ('filet_mignon', 'baby_back_ribs', 5),
#  ('filet_mignon', 'grilled_salmon', 5),
#  ('fish_and_chips', 'french_fries', 5),
#  ('fish_and_chips', 'lobster_roll_sandwich', 5),
#  ('foie_gras', 'beet_salad', 5),
#  ('foie_gras', 'chocolate_mousse', 5),
#  ('foie_gras', 'panna_cotta', 5),
#  ('french_toast', 'gyoza', 5),
#  ('fried_rice', 'pad_thai', 5),
#  ('gnocchi', 'scallops', 5),
#  ('grilled_cheese_sandwich', 'french_toast', 5),
#  ('grilled_cheese_sandwich', 'omelette', 5),
#  ('hot_and_sour_soup', 'miso_soup', 5),
#  ('huevos_rancheros', 'croque_madame', 5),
#  ('huevos_rancheros', 'lasagna', 5),
#  ('ice_cream', 'strawberry_shortcake', 5),
#  ('ice_cream', 'waffles', 5),
#  ('lasagna', 'omelette', 5),
#  ('lasagna', 'ravioli', 5),
#  ('lobster_roll_sandwich', 'pulled_pork_sandwich', 5),
#  ('nachos', 'tacos', 5),
#  ('panna_cotta', 'cheesecake', 5),
#  ('pork_chop', 'chicken_wings', 5),
#  ('pork_chop', 'crab_cakes', 5),
#  ('ramen', 'hot_and_sour_soup', 5),
#  ('ramen', 'pad_thai', 5),
#  ('ravioli', 'deviled_eggs', 5),
#  ('sashimi', 'sushi', 5),
#  ('scallops', 'gnocchi', 5),
#  ('shrimp_and_grits', 'huevos_rancheros', 5),
#  ('steak', 'foie_gras', 5),
#  ('tacos', 'caesar_salad', 5),
#  ('tacos', 'takoyaki', 5),
#  ('tiramisu', 'panna_cotta', 5),
#  ('tuna_tartare', 'beet_salad', 5),
#  ('tuna_tartare', 'bruschetta', 5),
#  ('waffles', 'pancakes', 5),
#  ('apple_pie', 'grilled_cheese_sandwich', 4),
#  ('apple_pie', 'pancakes', 4),
#  ('baby_back_ribs', 'pork_chop', 4),
#  ('baby_back_ribs', 'prime_rib', 4),
#  ('baklava', 'bread_pudding', 4),
#  ('baklava', 'cannoli', 4),
#  ('beef_carpaccio', 'bruschetta', 4),
#  ('beet_salad', 'scallops', 4),
#  ('beignets', 'cheese_plate', 4),
#  ('beignets', 'donuts', 4),
#  ('bibimbap', 'huevos_rancheros', 4),
#  ('bibimbap', 'pad_thai', 4),
#  ('bread_pudding', 'baby_back_ribs', 4),
#  ('bread_pudding', 'eggs_benedict', 4),
#  ('bread_pudding', 'macaroni_and_cheese', 4),
#  ('breakfast_burrito', 'eggs_benedict', 4),
#  ('breakfast_burrito', 'tacos', 4),
#  ('bruschetta', 'beef_carpaccio', 4),
#  ('caesar_salad', 'club_sandwich', 4),
#  ('caesar_salad', 'tacos', 4),
#  ('caprese_salad', 'sashimi', 4),
#  ('carrot_cake', 'tiramisu', 4),
#  ('ceviche', 'greek_salad', 4),
#  ('cheese_plate', 'sushi', 4),
#  ('cheesecake', 'cheese_plate', 4),
#  ('cheesecake', 'cup_cakes', 4),
#  ('cheesecake', 'red_velvet_cake', 4),
#  ('chicken_curry', 'lobster_bisque', 4),
#  ('chicken_quesadilla', 'cheese_plate', 4),
#  ('chicken_wings', 'pork_chop', 4),
#  ('chocolate_cake', 'filet_mignon', 4),
#  ('chocolate_mousse', 'foie_gras', 4),
#  ('chocolate_mousse', 'frozen_yogurt', 4),
#  ('chocolate_mousse', 'strawberry_shortcake', 4),
#  ('churros', 'onion_rings', 4),
#  ('clam_chowder', 'croque_madame', 4),
#  ('clam_chowder', 'macaroni_and_cheese', 4),
#  ('clam_chowder', 'mussels', 4),
#  ('creme_brulee', 'ice_cream', 4),
#  ('croque_madame', 'eggs_benedict', 4),
#  ('croque_madame', 'hamburger', 4),
#  ('deviled_eggs', 'cup_cakes', 4),
#  ('falafel', 'hot_dog', 4),
#  ('falafel', 'huevos_rancheros', 4),
#  ('falafel', 'lobster_roll_sandwich', 4),
#  ('filet_mignon', 'gnocchi', 4),
#  ('fish_and_chips', 'chicken_wings', 4),
#  ('french_fries', 'poutine', 4),
#  ('french_onion_soup', 'clam_chowder', 4),
#  ('french_onion_soup', 'hot_and_sour_soup', 4),
#  ('french_toast', 'omelette', 4),
#  ('french_toast', 'strawberry_shortcake', 4),
#  ('fried_rice', 'paella', 4),
#  ('frozen_yogurt', 'ice_cream', 4),
#  ('garlic_bread', 'apple_pie', 4),
#  ('garlic_bread', 'baklava', 4),
#  ('garlic_bread', 'chicken_quesadilla', 4),
#  ('garlic_bread', 'grilled_cheese_sandwich', 4),
#  ('gnocchi', 'ceviche', 4),
#  ('grilled_cheese_sandwich', 'grilled_salmon', 4),
#  ('grilled_salmon', 'filet_mignon', 4),
#  ('grilled_salmon', 'grilled_cheese_sandwich', 4),
#  ('guacamole', 'greek_salad', 4),
#  ('hamburger', 'hot_dog', 4),
#  ('hamburger', 'pancakes', 4),
#  ('hot_and_sour_soup', 'chicken_curry', 4),
#  ('hot_dog', 'lobster_roll_sandwich', 4),
#  ('huevos_rancheros', 'beet_salad', 4),
#  ('huevos_rancheros', 'bruschetta', 4),
#  ('huevos_rancheros', 'eggs_benedict', 4),
#  ('huevos_rancheros', 'tacos', 4),
#  ('hummus', 'cheese_plate', 4),
#  ('hummus', 'falafel', 4),
#  ('hummus', 'greek_salad', 4),
#  ('ice_cream', 'bread_pudding', 4),
#  ('ice_cream', 'cup_cakes', 4),
#  ('ice_cream', 'donuts', 4),
#  ('lasagna', 'garlic_bread', 4),
#  ('lasagna', 'huevos_rancheros', 4),
#  ('lobster_bisque', 'panna_cotta', 4),
#  ('macaroni_and_cheese', 'fried_calamari', 4),
#  ('macaroni_and_cheese', 'fried_rice', 4),
#  ('mussels', 'oysters', 4),
#  ('nachos', 'chicken_quesadilla', 4),
#  ('omelette', 'breakfast_burrito', 4),
#  ('pad_thai', 'bibimbap', 4),
#  ('paella', 'fried_calamari', 4),
#  ('paella', 'mussels', 4),
#  ('paella', 'nachos', 4),
#  ('peking_duck', 'spring_rolls', 4),
#  ('pizza', 'bruschetta', 4),
#  ('pizza', 'lasagna', 4),
#  ('pork_chop', 'escargots', 4),
#  ('pulled_pork_sandwich', 'pad_thai', 4),
#  ('ramen', 'pho', 4),
#  ('ravioli', 'chicken_curry', 4),
#  ('ravioli', 'foie_gras', 4),
#  ('ravioli', 'risotto', 4),
#  ('ravioli', 'spaghetti_bolognese', 4),
#  ('red_velvet_cake', 'ice_cream', 4),
#  ('red_velvet_cake', 'tiramisu', 4),
#  ('risotto', 'ravioli', 4),
#  ('risotto', 'shrimp_and_grits', 4),
#  ('samosa', 'gyoza', 4),
#  ('scallops', 'deviled_eggs', 4),
#  ('scallops', 'grilled_salmon', 4),
#  ('scallops', 'panna_cotta', 4),
#  ('shrimp_and_grits', 'risotto', 4),
#  ('spring_rolls', 'grilled_salmon', 4),
#  ('strawberry_shortcake', 'chocolate_mousse', 4),
#  ('strawberry_shortcake', 'cup_cakes', 4),
#  ('strawberry_shortcake', 'panna_cotta', 4),
#  ('sushi', 'cheese_plate', 4),
#  ('sushi', 'lobster_roll_sandwich', 4),
#  ('takoyaki', 'donuts', 4),
#  ('tuna_tartare', 'filet_mignon', 4),
#  ('tuna_tartare', 'foie_gras', 4),
#  ('waffles', 'cannoli', 4),
#  ('apple_pie', 'cannoli', 3),
#  ('apple_pie', 'carrot_cake', 3),
#  ('apple_pie', 'chocolate_mousse', 3),
#  ('apple_pie', 'croque_madame', 3),
#  ('apple_pie', 'macarons', 3),
#  ('baby_back_ribs', 'hamburger', 3),
#  ('baby_back_ribs', 'peking_duck', 3),
#  ('baklava', 'foie_gras', 3),
#  ('baklava', 'samosa', 3),
#  ('beef_carpaccio', 'caprese_salad', 3),
#  ('beef_tartare', 'beet_salad', 3),
#  ('beef_tartare', 'ceviche', 3),
#  ('beef_tartare', 'cheese_plate', 3),
#  ('beet_salad', 'bread_pudding', 3),
#  ('beet_salad', 'caesar_salad', 3),
#  ('beet_salad', 'mussels', 3),
#  ('beet_salad', 'nachos', 3),
#  ('beet_salad', 'panna_cotta', 3),
#  ('beignets', 'cannoli', 3),
#  ('beignets', 'chicken_wings', 3),
#  ('bibimbap', 'fried_rice', 3),
#  ('bread_pudding', 'french_onion_soup', 3),
#  ('bread_pudding', 'strawberry_shortcake', 3),
#  ('breakfast_burrito', 'club_sandwich', 3),
#  ('breakfast_burrito', 'huevos_rancheros', 3),
#  ('breakfast_burrito', 'samosa', 3),
#  ('bruschetta', 'lobster_roll_sandwich', 3),
#  ('bruschetta', 'pizza', 3),
#  ('bruschetta', 'takoyaki', 3),
#  ('bruschetta', 'tuna_tartare', 3),
#  ('cannoli', 'beignets', 3),
#  ('cannoli', 'donuts', 3),
#  ('caprese_salad', 'eggs_benedict', 3),
#  ('caprese_salad', 'huevos_rancheros', 3),
#  ('caprese_salad', 'scallops', 3),
#  ('carrot_cake', 'risotto', 3),
#  ('ceviche', 'lobster_roll_sandwich', 3),
#  ('ceviche', 'nachos', 3),
#  ('ceviche', 'scallops', 3),
#  ('ceviche', 'tuna_tartare', 3),
#  ('cheese_plate', 'churros', 3),
#  ('cheese_plate', 'peking_duck', 3),
#  ('cheesecake', 'ice_cream', 3),
#  ('chicken_curry', 'chicken_quesadilla', 3),
#  ('chicken_curry', 'clam_chowder', 3),
#  ('chicken_curry', 'fried_rice', 3),
#  ('chicken_curry', 'gnocchi', 3),
#  ('chicken_curry', 'huevos_rancheros', 3),
#  ('chicken_curry', 'hummus', 3),
#  ('chicken_curry', 'ramen', 3),
#  ('chicken_curry', 'ravioli', 3),
#  ('chicken_curry', 'shrimp_and_grits', 3),
#  ('chicken_quesadilla', 'breakfast_burrito', 3),
#  ('chicken_quesadilla', 'caesar_salad', 3),
#  ('chicken_quesadilla', 'huevos_rancheros', 3),
#  ('chicken_quesadilla', 'hummus', 3),
#  ('chicken_wings', 'baby_back_ribs', 3),
#  ('chocolate_cake', 'cup_cakes', 3),
#  ('chocolate_cake', 'panna_cotta', 3),
#  ('chocolate_cake', 'tiramisu', 3),
#  ('chocolate_mousse', 'cheesecake', 3),
#  ('chocolate_mousse', 'churros', 3),
#  ('chocolate_mousse', 'ice_cream', 3),
#  ('chocolate_mousse', 'lobster_bisque', 3),
#  ('churros', 'cannoli', 3),
#  ('churros', 'french_toast', 3),
#  ('clam_chowder', 'gnocchi', 3),
#  ('clam_chowder', 'ravioli', 3),
#  ('club_sandwich', 'french_fries', 3),
#  ('crab_cakes', 'caesar_salad', 3),
#  ('crab_cakes', 'filet_mignon', 3),
#  ('crab_cakes', 'fish_and_chips', 3),
#  ('crab_cakes', 'omelette', 3),
#  ('creme_brulee', 'carrot_cake', 3),
#  ('creme_brulee', 'frozen_yogurt', 3),
#  ('croque_madame', 'baklava', 3),
#  ('croque_madame', 'grilled_cheese_sandwich', 3),
#  ('croque_madame', 'omelette', 3),
#  ('cup_cakes', 'red_velvet_cake', 3),
#  ('donuts', 'apple_pie', 3),
#  ('donuts', 'ice_cream', 3),
#  ('escargots', 'oysters', 3),
#  ('escargots', 'scallops', 3),
#  ('falafel', 'breakfast_burrito', 3),
#  ('falafel', 'caesar_salad', 3),
#  ('falafel', 'crab_cakes', 3),
#  ('falafel', 'filet_mignon', 3),
#  ('falafel', 'greek_salad', 3),
#  ('filet_mignon', 'chocolate_cake', 3),
#  ('filet_mignon', 'foie_gras', 3),
#  ('fish_and_chips', 'grilled_cheese_sandwich', 3),
#  ('foie_gras', 'cheesecake', 3),
#  ('foie_gras', 'chicken_curry', 3),
#  ('foie_gras', 'crab_cakes', 3),
#  ('foie_gras', 'garlic_bread', 3),
#  ('foie_gras', 'prime_rib', 3),
#  ('foie_gras', 'tuna_tartare', 3),
#  ('french_fries', 'cheese_plate', 3),
#  ('french_fries', 'fish_and_chips', 3),
#  ('french_onion_soup', 'apple_pie', 3),
#  ('french_onion_soup', 'ramen', 3),
#  ('french_toast', 'baby_back_ribs', 3),
#  ('french_toast', 'grilled_cheese_sandwich', 3),
#  ('fried_calamari', 'gnocchi', 3),
#  ('frozen_yogurt', 'strawberry_shortcake', 3),
#  ('frozen_yogurt', 'waffles', 3),
#  ('garlic_bread', 'lasagna', 3),
#  ('garlic_bread', 'pizza', 3),
#  ('gnocchi', 'bruschetta', 3),
#  ('gnocchi', 'lasagna', 3),
#  ('gnocchi', 'macaroni_and_cheese', 3),
#  ('gnocchi', 'ravioli', 3),
#  ('gnocchi', 'seaweed_salad', 3),
#  ('grilled_cheese_sandwich', 'croque_madame', 3),
#  ('grilled_cheese_sandwich', 'garlic_bread', 3),
#  ('grilled_cheese_sandwich', 'hamburger', 3),
#  ('grilled_cheese_sandwich', 'pulled_pork_sandwich', 3),
#  ('grilled_cheese_sandwich', 'samosa', 3),
#  ('grilled_salmon', 'caesar_salad', 3),
#  ('grilled_salmon', 'cannoli', 3),
#  ('grilled_salmon', 'paella', 3),
#  ('grilled_salmon', 'peking_duck', 3),
#  ('grilled_salmon', 'sashimi', 3),
#  ('grilled_salmon', 'scallops', 3),
#  ('guacamole', 'cheese_plate', 3),
#  ('guacamole', 'nachos', 3),
#  ('gyoza', 'lasagna', 3),
#  ('hot_and_sour_soup', 'poutine', 3),
#  ('hot_dog', 'baklava', 3),
#  ('hot_dog', 'club_sandwich', 3),
#  ('hot_dog', 'french_fries', 3),
#  ('hot_dog', 'grilled_cheese_sandwich', 3),
#  ('hot_dog', 'hamburger', 3),
#  ('huevos_rancheros', 'bibimbap', 3),
#  ('huevos_rancheros', 'chicken_quesadilla', 3),
#  ('huevos_rancheros', 'omelette', 3),
#  ('hummus', 'cheesecake', 3),
#  ('hummus', 'creme_brulee', 3),
#  ('hummus', 'garlic_bread', 3),
#  ('hummus', 'pancakes', 3),
#  ('hummus', 'ravioli', 3),
#  ('ice_cream', 'cannoli', 3),
#  ('ice_cream', 'chocolate_cake', 3),
#  ('ice_cream', 'macarons', 3),
#  ('lasagna', 'apple_pie', 3),
#  ('lasagna', 'chicken_curry', 3),
#  ('lobster_bisque', 'miso_soup', 3),
#  ('lobster_roll_sandwich', 'hamburger', 3),
#  ('lobster_roll_sandwich', 'hot_dog', 3),
#  ('macaroni_and_cheese', 'crab_cakes', 3),
#  ('macaroni_and_cheese', 'french_fries', 3),
#  ('macarons', 'cup_cakes', 3),
#  ('nachos', 'breakfast_burrito', 3),
#  ('nachos', 'ceviche', 3),
#  ('nachos', 'huevos_rancheros', 3),
#  ('omelette', 'beef_carpaccio', 3),
#  ('omelette', 'beef_tartare', 3),
#  ('omelette', 'eggs_benedict', 3),
#  ('omelette', 'filet_mignon', 3),
#  ('omelette', 'fish_and_chips', 3),
#  ('omelette', 'garlic_bread', 3),
#  ('omelette', 'lobster_roll_sandwich', 3),
#  ('omelette', 'shrimp_and_grits', 3),
#  ('onion_rings', 'french_fries', 3),
#  ('oysters', 'bibimbap', 3),
#  ('oysters', 'sushi', 3),
#  ('pad_thai', 'fried_rice', 3),
#  ('pad_thai', 'nachos', 3),
#  ('pad_thai', 'spaghetti_bolognese', 3),
#  ('paella', 'huevos_rancheros', 3),
#  ('pancakes', 'bread_pudding', 3),
#  ('pancakes', 'grilled_cheese_sandwich', 3),
#  ('pancakes', 'huevos_rancheros', 3),
#  ('pancakes', 'omelette', 3),
#  ('pancakes', 'peking_duck', 3),
#  ('pancakes', 'waffles', 3),
#  ('panna_cotta', 'frozen_yogurt', 3),
#  ('panna_cotta', 'hummus', 3),
#  ('panna_cotta', 'lobster_bisque', 3),
#  ('panna_cotta', 'strawberry_shortcake', 3),
#  ('peking_duck', 'grilled_salmon', 3),
#  ('pizza', 'beef_carpaccio', 3),
#  ('pizza', 'garlic_bread', 3),
#  ('pork_chop', 'foie_gras', 3),
#  ('pork_chop', 'hamburger', 3),
#  ('pork_chop', 'scallops', 3),
#  ('poutine', 'french_fries', 3),
#  ('poutine', 'nachos', 3),
#  ('prime_rib', 'huevos_rancheros', 3),
#  ('ravioli', 'gnocchi', 3),
#  ('ravioli', 'grilled_salmon', 3),
#  ('ravioli', 'gyoza', 3),
#  ('ravioli', 'omelette', 3),
#  ('red_velvet_cake', 'cheesecake', 3),
#  ('red_velvet_cake', 'chocolate_cake', 3),
#  ('red_velvet_cake', 'panna_cotta', 3),
#  ('risotto', 'guacamole', 3),
#  ('risotto', 'macaroni_and_cheese', 3),
#  ('risotto', 'paella', 3),
#  ('samosa', 'fish_and_chips', 3),
#  ('samosa', 'spring_rolls', 3),
#  ('sashimi', 'foie_gras', 3),
#  ('scallops', 'oysters', 3),
#  ('seaweed_salad', 'bibimbap', 3),
#  ('seaweed_salad', 'chocolate_mousse', 3),
#  ('seaweed_salad', 'pad_thai', 3),
#  ('shrimp_and_grits', 'crab_cakes', 3),
#  ('shrimp_and_grits', 'pork_chop', 3),
#  ('shrimp_and_grits', 'ravioli', 3),
#  ('shrimp_and_grits', 'scallops', 3),
#  ('spaghetti_carbonara', 'macaroni_and_cheese', 3),
#  ('spaghetti_carbonara', 'pad_thai', 3),
#  ('spaghetti_carbonara', 'spaghetti_bolognese', 3),
#  ('spring_rolls', 'lobster_roll_sandwich', 3),
#  ('steak', 'beef_tartare', 3),
#  ('steak', 'beet_salad', 3),
#  ('steak', 'huevos_rancheros', 3),
#  ('strawberry_shortcake', 'frozen_yogurt', 3),
#  ('strawberry_shortcake', 'red_velvet_cake', 3),
#  ('sushi', 'cannoli', 3),
#  ('sushi', 'deviled_eggs', 3),
#  ('tacos', 'club_sandwich', 3),
#  ('tacos', 'falafel', 3),
#  ('tacos', 'fried_rice', 3),
#  ('tacos', 'greek_salad', 3),
#  ('tiramisu', 'cannoli', 3),
#  ('tiramisu', 'carrot_cake', 3),
#  ('tiramisu', 'cheesecake', 3),
#  ('tiramisu', 'foie_gras', 3),
#  ('tiramisu', 'strawberry_shortcake', 3),
#  ('tuna_tartare', 'beef_carpaccio', 3),
#  ('tuna_tartare', 'crab_cakes', 3),
#  ('tuna_tartare', 'samosa', 3),
#  ('waffles', 'eggs_benedict', 3),
#  ('waffles', 'french_toast', 3),
#  ('apple_pie', 'beignets', 2),
#  ('apple_pie', 'cheese_plate', 2),
#  ('apple_pie', 'dumplings', 2),
#  ('apple_pie', 'garlic_bread', 2),
#  ('apple_pie', 'gyoza', 2),
#  ('apple_pie', 'hummus', 2),
#  ('apple_pie', 'macaroni_and_cheese', 2),
#  ('apple_pie', 'omelette', 2),
#  ('apple_pie', 'peking_duck', 2),
#  ('apple_pie', 'pizza', 2),
#  ('apple_pie', 'risotto', 2),
#  ('apple_pie', 'samosa', 2),
#  ('apple_pie', 'takoyaki', 2),
#  ('baby_back_ribs', 'beet_salad', 2),
#  ('baby_back_ribs', 'chicken_wings', 2),
#  ('baby_back_ribs', 'fried_rice', 2),
#  ('baby_back_ribs', 'grilled_salmon', 2),
#  ('baby_back_ribs', 'gyoza', 2),
#  ('baby_back_ribs', 'mussels', 2),
#  ('baby_back_ribs', 'takoyaki', 2),
#  ('baklava', 'baby_back_ribs', 2),
#  ('baklava', 'beignets', 2),
#  ('baklava', 'cheese_plate', 2),
#  ('baklava', 'dumplings', 2),
#  ('baklava', 'filet_mignon', 2),
#  ('baklava', 'gyoza', 2),
#  ('baklava', 'hot_dog', 2),
#  ('baklava', 'hummus', 2),
#  ('baklava', 'steak', 2),
#  ('beef_carpaccio', 'beef_tartare', 2),
#  ('beef_carpaccio', 'lobster_roll_sandwich', 2),
#  ('beef_carpaccio', 'panna_cotta', 2),
#  ('beef_carpaccio', 'seaweed_salad', 2),
#  ('beef_carpaccio', 'tacos', 2),
#  ('beef_carpaccio', 'tuna_tartare', 2),
#  ('beef_tartare', 'bruschetta', 2),
#  ('beef_tartare', 'club_sandwich', 2),
#  ('beef_tartare', 'fish_and_chips', 2),
#  ('beef_tartare', 'grilled_salmon', 2),
#  ('beet_salad', 'beef_carpaccio', 2),
#  ('beet_salad', 'beef_tartare', 2),
#  ('beet_salad', 'bruschetta', 2),
#  ('beet_salad', 'caprese_salad', 2),
#  ('beet_salad', 'chocolate_cake', 2),
#  ('beet_salad', 'gnocchi', 2),
#  ('beet_salad', 'sashimi', 2),
#  ('beet_salad', 'seaweed_salad', 2),
#  ('beet_salad', 'tacos', 2),
#  ('beignets', 'bread_pudding', 2),
#  ('beignets', 'macarons', 2),
#  ('beignets', 'samosa', 2),
#  ('bibimbap', 'beet_salad', 2),
#  ('bibimbap', 'caesar_salad', 2),
#  ('bibimbap', 'croque_madame', 2),
#  ('bibimbap', 'omelette', 2),
#  ('bibimbap', 'seaweed_salad', 2),
#  ('bibimbap', 'spaghetti_bolognese', 2),
#  ('bread_pudding', 'breakfast_burrito', 2),
#  ('bread_pudding', 'croque_madame', 2),
#  ('bread_pudding', 'lasagna', 2),
#  ('bread_pudding', 'panna_cotta', 2),
#  ('bread_pudding', 'pizza', 2),
#  ('bread_pudding', 'pork_chop', 2),
#  ('bread_pudding', 'tuna_tartare', 2),
#  ('bread_pudding', 'waffles', 2),
#  ('breakfast_burrito', 'apple_pie', 2),
#  ('breakfast_burrito', 'ceviche', 2),
#  ('breakfast_burrito', 'guacamole', 2),
#  ('breakfast_burrito', 'lasagna', 2),
#  ('breakfast_burrito', 'nachos', 2),
#  ('breakfast_burrito', 'oysters', 2),
#  ('breakfast_burrito', 'shrimp_and_grits', 2),
#  ('breakfast_burrito', 'spring_rolls', 2),
#  ('bruschetta', 'beef_tartare', 2),
#  ('bruschetta', 'beet_salad', 2),
#  ('bruschetta', 'cheese_plate', 2),
#  ('bruschetta', 'chicken_quesadilla', 2),
#  ('bruschetta', 'deviled_eggs', 2),
#  ('bruschetta', 'garlic_bread', 2),
#  ('bruschetta', 'huevos_rancheros', 2),
#  ('bruschetta', 'sushi', 2),
#  ('bruschetta', 'tacos', 2),
#  ('caesar_salad', 'beet_salad', 2),
#  ('caesar_salad', 'chicken_quesadilla', 2),
#  ('caesar_salad', 'guacamole', 2),
#  ('caesar_salad', 'nachos', 2),
#  ('caesar_salad', 'sushi', 2),
#  ('cannoli', 'lobster_roll_sandwich', 2),
#  ('cannoli', 'spring_rolls', 2),
#  ('caprese_salad', 'takoyaki', 2),
#  ('carrot_cake', 'cheesecake', 2),
#  ('carrot_cake', 'chocolate_mousse', 2),
#  ('carrot_cake', 'foie_gras', 2),
#  ('carrot_cake', 'ice_cream', 2),
#  ('carrot_cake', 'red_velvet_cake', 2),
#  ('ceviche', 'beet_salad', 2),
#  ('ceviche', 'caesar_salad', 2),
#  ('ceviche', 'chicken_quesadilla', 2),
#  ('ceviche', 'chocolate_mousse', 2),
#  ('ceviche', 'foie_gras', 2),
#  ('ceviche', 'huevos_rancheros', 2),
#  ('ceviche', 'macaroni_and_cheese', 2),
#  ('ceviche', 'ravioli', 2),
#  ('ceviche', 'shrimp_and_grits', 2),
#  ('cheese_plate', 'donuts', 2),
#  ('cheese_plate', 'filet_mignon', 2),
#  ('cheese_plate', 'grilled_salmon', 2),
#  ('cheese_plate', 'nachos', 2),
#  ('cheese_plate', 'omelette', 2),
#  ('cheese_plate', 'panna_cotta', 2),
#  ('cheesecake', 'baby_back_ribs', 2),
#  ('cheesecake', 'bread_pudding', 2),
#  ('cheesecake', 'chocolate_cake', 2),
#  ('cheesecake', 'foie_gras', 2),
#  ('cheesecake', 'garlic_bread', 2),
#  ('cheesecake', 'hummus', 2),
#  ('cheesecake', 'peking_duck', 2),
#  ('chicken_curry', 'fried_calamari', 2),
#  ('chicken_curry', 'garlic_bread', 2),
#  ('chicken_curry', 'lasagna', 2),
#  ('chicken_curry', 'pho', 2),
#  ('chicken_curry', 'pork_chop', 2),
#  ('chicken_curry', 'seaweed_salad', 2),
#  ('chicken_curry', 'steak', 2),
#  ('chicken_quesadilla', 'ceviche', 2),
#  ('chicken_quesadilla', 'club_sandwich', 2),
#  ('chicken_quesadilla', 'lobster_roll_sandwich', 2),
#  ('chicken_quesadilla', 'tacos', 2),
#  ('chicken_wings', 'filet_mignon', 2),
#  ('chicken_wings', 'fried_calamari', 2),
#  ('chicken_wings', 'onion_rings', 2),
#  ('chicken_wings', 'paella', 2),
#  ('chicken_wings', 'peking_duck', 2),
#  ('chicken_wings', 'poutine', 2),
#  ('chocolate_cake', 'bread_pudding', 2),
#  ('chocolate_mousse', 'beef_tartare', 2),
#  ('chocolate_mousse', 'bread_pudding', 2),
#  ('chocolate_mousse', 'carrot_cake', 2),
#  ('chocolate_mousse', 'cup_cakes', 2),
#  ('chocolate_mousse', 'mussels', 2),
#  ('chocolate_mousse', 'red_velvet_cake', 2),
#  ('churros', 'cheesecake', 2),
#  ('churros', 'waffles', 2),
#  ('clam_chowder', 'french_onion_soup', 2),
#  ('club_sandwich', 'chicken_quesadilla', 2),
#  ('club_sandwich', 'croque_madame', 2),
#  ('club_sandwich', 'falafel', 2),
#  ('club_sandwich', 'ice_cream', 2),
#  ('club_sandwich', 'lobster_roll_sandwich', 2),
#  ('club_sandwich', 'tiramisu', 2),
#  ('crab_cakes', 'caprese_salad', 2),
#  ('crab_cakes', 'chicken_wings', 2),
#  ('crab_cakes', 'croque_madame', 2),
#  ('crab_cakes', 'pad_thai', 2),
#  ('crab_cakes', 'pancakes', 2),
#  ('crab_cakes', 'waffles', 2),
#  ('creme_brulee', 'lobster_bisque', 2),
#  ('creme_brulee', 'miso_soup', 2),
#  ('creme_brulee', 'pancakes', 2),
#  ('creme_brulee', 'strawberry_shortcake', 2),
#  ('croque_madame', 'breakfast_burrito', 2),
#  ('croque_madame', 'grilled_salmon', 2),
#  ('croque_madame', 'huevos_rancheros', 2),
#  ('cup_cakes', 'carrot_cake', 2),
#  ('cup_cakes', 'pancakes', 2),
#  ('cup_cakes', 'strawberry_shortcake', 2),
#  ('deviled_eggs', 'bruschetta', 2),
#  ('deviled_eggs', 'caprese_salad', 2),
#  ('deviled_eggs', 'ceviche', 2),
#  ('deviled_eggs', 'cheesecake', 2),
#  ('deviled_eggs', 'greek_salad', 2),
#  ('deviled_eggs', 'hummus', 2),
#  ('deviled_eggs', 'scallops', 2),
#  ('donuts', 'cannoli', 2),
#  ('donuts', 'chicken_wings', 2),
#  ('donuts', 'chocolate_cake', 2),
#  ('donuts', 'cup_cakes', 2),
#  ('donuts', 'falafel', 2),
#  ('donuts', 'garlic_bread', 2),
#  ('donuts', 'hot_dog', 2),
#  ('donuts', 'macarons', 2),
#  ('dumplings', 'apple_pie', 2),
#  ('dumplings', 'cup_cakes', 2),
#  ('dumplings', 'donuts', 2),
#  ('dumplings', 'hot_and_sour_soup', 2),
#  ('dumplings', 'peking_duck', 2),
#  ('edamame', 'seaweed_salad', 2),
#  ('eggs_benedict', 'cheese_plate', 2),
#  ('eggs_benedict', 'crab_cakes', 2),
#  ('eggs_benedict', 'huevos_rancheros', 2),
#  ('eggs_benedict', 'omelette', 2),
#  ('eggs_benedict', 'scallops', 2),
#  ('escargots', 'beet_salad', 2),
#  ('escargots', 'deviled_eggs', 2),
#  ('escargots', 'filet_mignon', 2),
#  ('escargots', 'lasagna', 2),
#  ('escargots', 'pho', 2),
#  ('escargots', 'shrimp_and_grits', 2),
#  ('falafel', 'beef_tartare', 2),
#  ('falafel', 'beignets', 2),
#  ('falafel', 'cheese_plate', 2),
#  ('falafel', 'club_sandwich', 2),
#  ('falafel', 'hamburger', 2),
#  ('falafel', 'hummus', 2),
#  ('falafel', 'pulled_pork_sandwich', 2),
#  ('falafel', 'takoyaki', 2),
#  ('filet_mignon', 'beef_tartare', 2),
#  ('filet_mignon', 'beet_salad', 2),
#  ('filet_mignon', 'bread_pudding', 2),
#  ('filet_mignon', 'prime_rib', 2),
#  ('filet_mignon', 'pulled_pork_sandwich', 2),
#  ('filet_mignon', 'spaghetti_bolognese', 2),
#  ('filet_mignon', 'tuna_tartare', 2),
#  ('fish_and_chips', 'churros', 2),
#  ('fish_and_chips', 'club_sandwich', 2),
#  ('fish_and_chips', 'fried_calamari', 2),
#  ('fish_and_chips', 'omelette', 2),
#  ('fish_and_chips', 'onion_rings', 2),
#  ('fish_and_chips', 'samosa', 2),
#  ('fish_and_chips', 'spring_rolls', 2),
#  ('foie_gras', 'baby_back_ribs', 2),
#  ('foie_gras', 'chicken_wings', 2),
#  ('foie_gras', 'churros', 2),
#  ('foie_gras', 'club_sandwich', 2),
#  ('foie_gras', 'creme_brulee', 2),
#  ('foie_gras', 'eggs_benedict', 2),
#  ('foie_gras', 'filet_mignon', 2),
#  ('foie_gras', 'grilled_cheese_sandwich', 2),
#  ('foie_gras', 'grilled_salmon', 2),
#  ('foie_gras', 'hot_and_sour_soup', 2),
#  ('foie_gras', 'macarons', 2),
#  ('foie_gras', 'pancakes', 2),
#  ('foie_gras', 'risotto', 2),
#  ('foie_gras', 'sushi', 2),
#  ('foie_gras', 'waffles', 2),
#  ('french_fries', 'fried_calamari', 2),
#  ('french_fries', 'hot_dog', 2),
#  ('french_fries', 'ice_cream', 2),
#  ('french_fries', 'onion_rings', 2),
#  ('french_onion_soup', 'bread_pudding', 2),
#  ('french_onion_soup', 'chicken_curry', 2),
#  ('french_onion_soup', 'creme_brulee', 2),
#  ('french_onion_soup', 'lobster_bisque', 2),
#  ('french_onion_soup', 'miso_soup', 2),
#  ('french_toast', 'apple_pie', 2),
#  ('french_toast', 'chicken_wings', 2),
#  ('french_toast', 'churros', 2),
#  ('french_toast', 'croque_madame', 2),
#  ('french_toast', 'donuts', 2),
#  ('french_toast', 'fried_calamari', 2),
#  ('french_toast', 'peking_duck', 2),
#  ('french_toast', 'pork_chop', 2),
#  ('fried_calamari', 'crab_cakes', 2),
#  ('fried_calamari', 'fish_and_chips', 2),
#  ('fried_calamari', 'omelette', 2),
#  ('fried_calamari', 'poutine', 2),
#  ('fried_rice', 'bibimbap', 2),
#  ('fried_rice', 'nachos', 2),
#  ('fried_rice', 'omelette', 2),
#  ('fried_rice', 'risotto', 2),
#  ('frozen_yogurt', 'carrot_cake', 2),
#  ('frozen_yogurt', 'greek_salad', 2),
#  ('garlic_bread', 'carrot_cake', 2),
#  ('garlic_bread', 'donuts', 2),
#  ('garlic_bread', 'grilled_salmon', 2),
#  ('garlic_bread', 'hummus', 2),
#  ('garlic_bread', 'omelette', 2),
#  ('garlic_bread', 'pork_chop', 2),
#  ('garlic_bread', 'samosa', 2),
#  ('gnocchi', 'beet_salad', 2),
#  ('gnocchi', 'bread_pudding', 2),
#  ('gnocchi', 'chicken_curry', 2),
#  ('gnocchi', 'clam_chowder', 2),
#  ('gnocchi', 'eggs_benedict', 2),
#  ('gnocchi', 'escargots', 2),
#  ('gnocchi', 'filet_mignon', 2),
#  ('gnocchi', 'fried_calamari', 2),
#  ('gnocchi', 'oysters', 2),
#  ('gnocchi', 'risotto', 2),
#  ('gnocchi', 'spaghetti_bolognese', 2),
#  ('greek_salad', 'bibimbap', 2),
#  ('greek_salad', 'caprese_salad', 2),
#  ('greek_salad', 'tacos', 2),
#  ('grilled_cheese_sandwich', 'apple_pie', 2),
#  ('grilled_cheese_sandwich', 'baklava', 2),
#  ('grilled_cheese_sandwich', 'crab_cakes', 2),
#  ('grilled_cheese_sandwich', 'french_fries', 2),
#  ('grilled_cheese_sandwich', 'gyoza', 2),
#  ('grilled_cheese_sandwich', 'hot_dog', 2),
#  ('grilled_cheese_sandwich', 'lobster_bisque', 2),
#  ('grilled_cheese_sandwich', 'lobster_roll_sandwich', 2),
#  ('grilled_cheese_sandwich', 'pancakes', 2),
#  ('grilled_cheese_sandwich', 'pork_chop', 2),
#  ('grilled_cheese_sandwich', 'spring_rolls', 2),
#  ('grilled_salmon', 'bread_pudding', 2),
#  ('grilled_salmon', 'foie_gras', 2),
#  ('grilled_salmon', 'fried_calamari', 2),
#  ('grilled_salmon', 'omelette', 2),
#  ('grilled_salmon', 'poutine', 2),
#  ('grilled_salmon', 'shrimp_and_grits', 2),
#  ('grilled_salmon', 'spring_rolls', 2),
#  ('grilled_salmon', 'steak', 2),
#  ('grilled_salmon', 'tuna_tartare', 2),
#  ('guacamole', 'chicken_quesadilla', 2),
#  ('guacamole', 'hummus', 2),
#  ('guacamole', 'tuna_tartare', 2),
#  ('gyoza', 'apple_pie', 2),
#  ('gyoza', 'ceviche', 2),
#  ('gyoza', 'chicken_wings', 2),
#  ('gyoza', 'deviled_eggs', 2),
#  ('gyoza', 'grilled_cheese_sandwich', 2),
#  ('gyoza', 'macaroni_and_cheese', 2),
#  ('gyoza', 'peking_duck', 2),
#  ('gyoza', 'spring_rolls', 2),
#  ('hamburger', 'baby_back_ribs', 2),
#  ('hamburger', 'croque_madame', 2),
#  ('hamburger', 'cup_cakes', 2),
#  ('hamburger', 'eggs_benedict', 2),
#  ('hamburger', 'falafel', 2),
#  ('hamburger', 'grilled_salmon', 2),
#  ('hamburger', 'steak', 2),
#  ('hot_and_sour_soup', 'pho', 2),
#  ('hot_and_sour_soup', 'ramen', 2),
#  ('hot_and_sour_soup', 'shrimp_and_grits', 2),
#  ('hot_dog', 'apple_pie', 2),
#  ('hot_dog', 'cheese_plate', 2),
#  ('hot_dog', 'chocolate_cake', 2),
#  ('hot_dog', 'donuts', 2),
#  ('hot_dog', 'foie_gras', 2),
#  ('hot_dog', 'huevos_rancheros', 2),
#  ('hot_dog', 'poutine', 2),
#  ('hot_dog', 'pulled_pork_sandwich', 2),
#  ('hot_dog', 'takoyaki', 2),
#  ('huevos_rancheros', 'beef_carpaccio', 2),
#  ('huevos_rancheros', 'chicken_curry', 2),
#  ('huevos_rancheros', 'french_toast', 2),
#  ('huevos_rancheros', 'hamburger', 2),
#  ('huevos_rancheros', 'hummus', 2),
#  ('huevos_rancheros', 'lobster_roll_sandwich', 2),
#  ('huevos_rancheros', 'macaroni_and_cheese', 2),
#  ('huevos_rancheros', 'shrimp_and_grits', 2),
#  ('hummus', 'ceviche', 2),
#  ('hummus', 'chicken_curry', 2),
#  ('hummus', 'clam_chowder', 2),
#  ('hummus', 'grilled_cheese_sandwich', 2),
#  ('hummus', 'grilled_salmon', 2),
#  ('hummus', 'huevos_rancheros', 2),
#  ('hummus', 'lobster_bisque', 2),
#  ('hummus', 'macaroni_and_cheese', 2),
#  ('hummus', 'nachos', 2),
#  ('hummus', 'pizza', 2),
#  ('hummus', 'shrimp_and_grits', 2),
#  ('ice_cream', 'caprese_salad', 2),
#  ('ice_cream', 'carrot_cake', 2),
#  ('ice_cream', 'cheese_plate', 2),
#  ('ice_cream', 'eggs_benedict', 2),
#  ('ice_cream', 'sashimi', 2),
#  ('lasagna', 'beef_tartare', 2),
#  ('lasagna', 'bread_pudding', 2),
#  ('lasagna', 'caesar_salad', 2),
#  ('lasagna', 'croque_madame', 2),
#  ('lasagna', 'eggs_benedict', 2),
#  ('lasagna', 'grilled_salmon', 2),
#  ('lasagna', 'macaroni_and_cheese', 2),
#  ('lasagna', 'risotto', 2),
#  ('lasagna', 'shrimp_and_grits', 2),
#  ('lasagna', 'spaghetti_bolognese', 2),
#  ('lobster_bisque', 'chicken_curry', 2),
#  ('lobster_bisque', 'hummus', 2),
#  ('lobster_bisque', 'shrimp_and_grits', 2),
#  ('lobster_roll_sandwich', 'bruschetta', 2),
#  ('lobster_roll_sandwich', 'ceviche', 2),
#  ('lobster_roll_sandwich', 'club_sandwich', 2),
#  ('lobster_roll_sandwich', 'gyoza', 2),
#  ('lobster_roll_sandwich', 'takoyaki', 2),
#  ('macaroni_and_cheese', 'escargots', 2),
#  ('macaroni_and_cheese', 'garlic_bread', 2),
#  ('macaroni_and_cheese', 'gnocchi', 2),
#  ('macaroni_and_cheese', 'lasagna', 2),
#  ('macaroni_and_cheese', 'omelette', 2),
#  ('macaroni_and_cheese', 'pad_thai', 2),
#  ('macaroni_and_cheese', 'poutine', 2),
#  ('macaroni_and_cheese', 'risotto', 2),
#  ('macaroni_and_cheese', 'spaghetti_carbonara', 2),
#  ('macarons', 'donuts', 2),
#  ('miso_soup', 'chocolate_mousse', 2),
#  ('miso_soup', 'clam_chowder', 2),
#  ('miso_soup', 'frozen_yogurt', 2),
#  ('miso_soup', 'mussels', 2),
#  ('nachos', 'bruschetta', 2),
#  ('nachos', 'cheese_plate', 2),
#  ('nachos', 'falafel', 2),
#  ('nachos', 'hummus', 2),
#  ('nachos', 'omelette', 2),
#  ('omelette', 'apple_pie', 2),
#  ('omelette', 'cheese_plate', 2),
#  ('omelette', 'chicken_curry', 2),
#  ('omelette', 'french_toast', 2),
#  ('omelette', 'guacamole', 2),
#  ('omelette', 'lasagna', 2),
#  ('omelette', 'macaroni_and_cheese', 2),
#  ('omelette', 'nachos', 2),
#  ('omelette', 'pizza', 2),
#  ('omelette', 'ravioli', 2),
#  ('omelette', 'samosa', 2),
#  ('omelette', 'steak', 2),
#  ('omelette', 'tacos', 2),
#  ('onion_rings', 'fish_and_chips', 2),
#  ('oysters', 'crab_cakes', 2),
#  ('pad_thai', 'poutine', 2),
#  ('pad_thai', 'tacos', 2),
#  ('paella', 'caesar_salad', 2),
#  ('paella', 'ceviche', 2),
#  ('pancakes', 'apple_pie', 2),
#  ('pancakes', 'cheesecake', 2),
#  ('pancakes', 'creme_brulee', 2),
#  ('pancakes', 'french_onion_soup', 2),
#  ('panna_cotta', 'churros', 2),
#  ('panna_cotta', 'creme_brulee', 2),
#  ('panna_cotta', 'deviled_eggs', 2),
#  ('panna_cotta', 'macaroni_and_cheese', 2),
#  ('panna_cotta', 'miso_soup', 2),
#  ('panna_cotta', 'sashimi', 2),
#  ('panna_cotta', 'tiramisu', 2),
#  ('panna_cotta', 'tuna_tartare', 2),
#  ('peking_duck', 'baklava', 2),
#  ('peking_duck', 'churros', 2),
#  ('peking_duck', 'hot_dog', 2),
#  ('peking_duck', 'pho', 2),
#  ('peking_duck', 'pork_chop', 2),
#  ('peking_duck', 'steak', 2),
#  ('peking_duck', 'sushi', 2),
#  ('pho', 'caesar_salad', 2),
#  ('pho', 'hot_and_sour_soup', 2),
#  ('pho', 'miso_soup', 2),
#  ('pizza', 'chicken_curry', 2),
#  ('pizza', 'chicken_quesadilla', 2),
#  ('pizza', 'huevos_rancheros', 2),
#  ('pizza', 'macaroni_and_cheese', 2),
#  ('pizza', 'omelette', 2),
#  ('pizza', 'spaghetti_carbonara', 2),
#  ('pork_chop', 'beef_carpaccio', 2),
#  ('pork_chop', 'bruschetta', 2),
#  ('pork_chop', 'french_toast', 2),
#  ('pork_chop', 'gnocchi', 2),
#  ('pork_chop', 'omelette', 2),
#  ('pork_chop', 'poutine', 2),
#  ('poutine', 'baby_back_ribs', 2),
#  ('poutine', 'bread_pudding', 2),
#  ('poutine', 'macaroni_and_cheese', 2),
#  ('prime_rib', 'chicken_wings', 2),
#  ('prime_rib', 'foie_gras', 2),
#  ('prime_rib', 'pork_chop', 2),
#  ('pulled_pork_sandwich', 'beef_tartare', 2),
#  ('pulled_pork_sandwich', 'bibimbap', 2),
#  ...]

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot(suggestion=True)
# Out:
# Min numerical gradient: 2.75E-06
# Min loss divided by 10: 1.32E-07

# %%
learn.unfreeze()
learn.fit_one_cycle(2, max_lr=slice(1e-06, 1e-02))
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='2', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/2 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='495' class='' max='946', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       52.33% [495/946 03:15<02:58 1.9142]
#     </div>
